# %%
multiprocessing = [408.9051730632782,
 226.10282611846924,
 167.7237000465393,
 140.21342182159424,
 119.93955707550049,
 128.39286494255066,
 119.31886696815491,
 130.32166194915771,
 115.92104601860046,
 123.1021180152893,
 118.33470296859741,
 116.16147470474243]

pymp = [421.2469379901886,
 221.1995861530304,
 156.56524109840393,
 125.66569709777832,
 110.58157896995544,
 101.94848299026489,
 101.3716561794281,
 101.90409779548645,
 96.30528831481934,
 100.03454804420471,
 95.89168906211853,
 94.81819891929626]

joblib = [416.2002320289612,
 223.3727080821991,
 161.57163906097412,
 135.62369179725647,
 125.90607500076294,
 115.64101099967957,
 122.25388288497925,
 115.64423704147339,
 117.15916085243225,
 114.12886786460876,
 114.89143919944763,
 112.76458072662354]

ray = [440.04772186279297,
 236.67144107818604,
 177.25566387176514,
 155.24097204208374,
 139.06487917900085,
 146.13371992111206,
 139.04324221611023,
 136.83588290214539,
 137.06418204307556,
 146.62162613868713,
 144.90116000175476,
 144.961040019989]

cores = [i+1 for i in range(12)]

# %%
import matplotlib.pyplot as plt
import numpy as np

barWidth = 0.20
fig = plt.subplots(figsize=(20, 10))
 
# set height of bar
types = cores

# Set position of bar on X axis
br1 = np.arange(len(multiprocessing))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]


# Make the plot
plt.bar(br2, multiprocessing, color ='r', width = barWidth,
        edgecolor ='grey', label ='Multiprocessing')

plt.bar(br1, pymp, color ='b', width = barWidth,
        edgecolor ='grey', label ='Pymp')

plt.bar(br3, joblib, color ='y', width = barWidth,
        edgecolor ='grey', label ='Joblib')

plt.bar(br4, ray, color ='g', width = barWidth,
        edgecolor ='grey', label ='Ray')
 
# Adding Xticks
plt.xlabel('Cores', fontweight ='bold', fontsize = 15)
plt.ylabel('Time', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth*1.5 for r in range(len(multiprocessing))],types)
 
plt.legend()
plt.show()
